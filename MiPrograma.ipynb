# %%
# !cp /content/drive/MyDrive/TECNICAS_DE_PROGRAMACION/EXAMENSEMANA06/MiLibreria/Milibreria.py /content/

# %%
import Milibreria
# Out:
# La suma de 10 y 20 es: 30
# La resta de 10 y 20 es: -10

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
